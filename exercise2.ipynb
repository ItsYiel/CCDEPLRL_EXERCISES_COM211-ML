# %% [markdown]
# <a href="https://colab.research.google.com/github/marielollage/CCDEPLRL_EXERCISES_COM211-ML/blob/main/exercise2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. What is the predicted output? (20 points)
#
# Answer:
#
# The predicted output, denoted as
# 𝑧
# 2
# z
# 2
# ​
#  , is equal to
# 𝑧
# 1
# z
# 1
# ​
#   multiplied by the weight
# 𝑤
# 1
# w
# 1
# ​
#  . Therefore,
# 𝑧
# 2
# =
# 𝑧
# 1
# ×
# 𝑤
# 1
# =
# 2.0
# ×
# 2.0
# =
# 4.0
# z
# 2
# ​
#  =z
# 1
# ​
#  ×w
# 1
# ​
#  =2.0×2.0=4.0.

# %% [markdown]
# 2. Find the loss using the Mean Squared Error (MSE) function (20 points)
#
# Answer:
#
# Loss using Mean Squared Error (MSE) function:The Mean Squared Error (MSE) is given by:
# 𝑀
# 𝑆
# 𝐸
# =
# 1
# 𝑁
# ∑
# 𝑖
# =
# 1
# 𝑁
# (
# 𝑦
# 𝑖
# −
# 𝑦
# 𝑖
# ^
# )
# 2
# MSE=
# N
# 1
# ​
#  ∑
# i=1
# N
# ​
#  (y
# i
# ​
#  −
# y
# i
# ​
#
# ^
# ​
#  )
# 2
#  Given
# 𝑦
# =
# 1
# y=1 and
# 𝑦
# ^
# =
# 4.0
# y
# ^
# ​
#  =4.0, we can compute the MSE.
# 𝑀
# 𝑆
# 𝐸
# =
# 1
# 1
# ×
# (
# 1
# −
# 4.0
# )
# 2
# =
# 9.0
# MSE=
# 1
# 1
# ​
#  ×(1−4.0)
# 2
#  =9.0

# %% [markdown]
# 3. What is the derivative of z2
#  with respect to w1
# ? (20 points)
#
# Answer:
#
# Derivative of
# 𝑧
# 2
# z
# 2
# ​
#   with respect to
# 𝑤
# 1
# w
# 1
# ​
#  :Since
# 𝑧
# 2
# =
# 𝑧
# 1
# ×
# 𝑤
# 1
# z
# 2
# ​
#  =z
# 1
# ​
#  ×w
# 1
# ​
#  , the derivative of
# 𝑧
# 2
# z
# 2
# ​
#   with respect to
# 𝑤
# 1
# w
# 1
# ​
#   is simply
# 𝑧
# 1
# z
# 1
# ​
#  , which is
# 2.0

# %% [markdown]
# 4. What is the derivative of the loss with respect to z2? (20 points)
#
# Answer:
# Derivative of the loss with respect to
# 𝑧
# 2
# z
# 2
# ​
#  :The derivative of the loss with respect to
# 𝑧
# 2
# z
# 2
# ​
#   depends on the loss function used. Since we are using Mean Squared Error (MSE), the derivative of the loss with respect to
# 𝑧
# 2
# z
# 2
# ​
#   is
# 2
# ×
# (
# 𝑦
# −
# 𝑦
# ^
# )
# 2×(y−
# y
# ^
# ​
#  ).
# ∂
# 𝐿
# 𝑜
# 𝑠
# 𝑠
# ∂
# 𝑧
# 2
# =
# 2
# ×
# (
# 𝑦
# −
# 𝑦
# ^
# )
# =
# 2
# ×
# (
# 1
# −
# 4.0
# )
# =
# −
# 6.0
# ∂z
# 2
# ​
#
# ∂Loss
# ​
#  =2×(y−
# y
# ^
# ​
#  )=2×(1−4.0)=−6.0

# %% [markdown]
# 5. What is the derivative of the loss with respect to
# w1? (20 points)
#
# Answer:
#
# Derivative of the loss with respect to
# 𝑤
# 1
# w
# 1
# ​
#  :We can use the chain rule to find the derivative of the loss with respect to
# 𝑤
# 1
# w
# 1
# ​
#  . It's the product of the derivatives of the loss with respect to
# 𝑧
# 2
# z
# 2
# ​
#   and
# 𝑧
# 2
# z
# 2
# ​
#   with respect to
# 𝑤
# 1
# w
# 1
# ​
#  .
# ∂
# 𝐿
# 𝑜
# 𝑠
# 𝑠
# ∂
# 𝑤
# 1
# =
# ∂
# 𝐿
# 𝑜
# 𝑠
# 𝑠
# ∂
# 𝑧
# 2
# ×
# ∂
# 𝑧
# 2
# ∂
# 𝑤
# 1
# =
# −
# 6.0
# ×
# 2.0
# =
# −
# 12.0
# ∂w
# 1
# ​
#
# ∂Loss
# ​
#  =
# ∂z
# 2
# ​
#
# ∂Loss
# ​
#  ×
# ∂w
# 1
# ​
#
# ∂z
# 2
# ​
#
# ​
#  =−6.0×2.0=−12.0
